# %%
# %matplotlib inline  

import pandas
import matplotlib.pyplot as plt

df = pandas.read_csv("experiment.csv")
df["experiments"].plot()
plt.title('Experimental data')
plt.show()

# %%
df.plot.kde()

# %%
from scipy import stats
print(stats.kstest(df, 'norm', (df.mean(), df.std())))
# Out:
# KstestResult(statistic=0.9860265227877092, pvalue=3.6834480313303553e-93)
